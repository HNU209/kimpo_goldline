# %%
import pandas as pd

# %%
bus_rate = [
    ['걸포마루공원', '걸포북변역.국민연금공단', 565, 0.007799999999999975, 1],
    ['걸포마루공원', '풍무역', 334, 0.0046, 1],
    ['걸포마루공원', '고촌역', 439, 0.0061, 1],
    ['걸포마루공원', '개화역광역환승센터', 163, 0.0022	, 1],
    ['걸포마루공원', '롯데몰.김포공항역', 163, 0.0022, 1],
    
    ['걸포북변역.국민연금공단', '풍무역', 334, 0.0046, 1],
    ['걸포북변역.국민연금공단', '고촌역', 439, 0.0061, 1],
    ['걸포북변역.국민연금공단', '개화역광역환승센터', 163, 0.0022, 1],
    ['걸포북변역.국민연금공단', '롯데몰.김포공항역', 163, 0.0022, 1],
    
    ['풍무역', '걸포북변역.국민연금공단', 387, 0.0053, 2],
    ['풍무역', '고촌역', 706, 0.0097, 1],
    ['풍무역', '개화역광역환승센터', 198, 0.0027, 1],
    ['풍무역', '롯데몰.김포공항역', 198, 0.0027, 1],
    
    ['고촌역', '걸포북변역.국민연금공단', 378, 0.0052, 2],
    ['고촌역', '풍무역', 791, 0.0109, 2],
    ['고촌역', '개화역광역환승센터', 163, 0.0022, 1],
    ['고촌역', '롯데몰.김포공항역', 239, 0.0033, 1],
    
    ['개화역광역환승센터', '걸포북변역.국민연금공단', 154, 0.0021, 2],
    ['개화역광역환승센터', '풍무역', 266, 0.0037, 2],
    ['개화역광역환승센터', '고촌역', 253, 0.0035, 2],
    ['개화역광역환승센터', '롯데몰.김포공항역', 163, 0.0022, 1],
    
    ['롯데몰.김포공항역', '걸포북변역.국민연금공단', 154, 0.0021, 2],
    ['롯데몰.김포공항역', '풍무역', 266, 0.0037, 2],
    ['롯데몰.김포공항역', '고촌역', 253, 0.0035, 2],
    ['롯데몰.김포공항역', '개화역광역환승센터', 163, 0.0022, 2],
]

bus_rate = pd.DataFrame(bus_rate, columns=['정류장 명칭_승차', '정류장 명칭_하차', 'count', 'rate', 'direction'])
bus_rate['rate'] = bus_rate['count'].map(lambda x: round(x / bus_rate['count'].sum() * 100, 2)) / 100
bus_rate
# Out:
#        정류장 명칭_승차     정류장 명칭_하차  count    rate  direction
# 0         걸포마루공원  걸포북변역.국민연금공단    565  0.0754          1
# 1         걸포마루공원           풍무역    334  0.0446          1
# 2         걸포마루공원           고촌역    439  0.0586          1
# 3         걸포마루공원     개화역광역환승센터    163  0.0217          1
# 4         걸포마루공원     롯데몰.김포공항역    163  0.0217          1
# 5   걸포북변역.국민연금공단           풍무역    334  0.0446          1
# 6   걸포북변역.국민연금공단           고촌역    439  0.0586          1
# 7   걸포북변역.국민연금공단     개화역광역환승센터    163  0.0217          1
# 8   걸포북변역.국민연금공단     롯데몰.김포공항역    163  0.0217          1
# 9            풍무역  걸포북변역.국민연금공단    387  0.0516          2
# 10           풍무역           고촌역    706  0.0942          1
# 11           풍무역     개화역광역환승센터    198  0.0264          1
# 12           풍무역     롯데몰.김포공항역    198  0.0264          1
# 13           고촌역  걸포북변역.국민연금공단    378  0.0504          2
# 14           고촌역           풍무역    791  0.1055          2
# ...

# %%
bus_rate.to_csv('data/passenger/bus_rate.csv', index=None)
